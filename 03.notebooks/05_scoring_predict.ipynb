# %%
#1. Ajuste de rutas de tu red del proyecto
import sys
import os
sys.path.append(os.path.abspath(".."))
sys.path.append(os.path.abspath("../src"))

# %%
#2. Importación de la función de scoring
from src.scoring.predict import run_scoring

run_scoring(
    input_csv="../01.data/scoring/clientes_nuevos.csv",
    model_path="../01.models/pipeline_xgboost_telco.pkl",
    output_path="../01.data/scoring/scoring_resultado.csv"
)
print("\n🎉 ¡PROCESO TERMINADO! El entorno portátil ejecutó el scoring perfectamente.")
# Out:
# 📥 Cargando datos nuevos de clientes...
# 🧠 Cargando Pipeline de Machine Learning...
# 🔮 Ejecutando inferencia automatizada...
# Generando probabilidades en lote...
# 💾 Almacenando base de datos enriquecida...
# ✅ Archivo guardado con éxito en: ../01.data/scoring/scoring_resultado.csv
#
# 🎉 ¡PROCESO TERMINADO! El entorno portátil ejecutó el scoring perfectamente.
